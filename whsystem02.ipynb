# %%
from whfiles.systems.whsystem02 import futures_system
# Out:
# Configuring sim logging

# %%
system=futures_system()
# Out:
# Private configuration private/private_config.yaml does not exist; no problem if running in sim mode

# %%
system
# Out:
# System base_system with .config, .data, and .stages: accounts, portfolio, positionSize, rawdata, combForecast, forecastScaleCap, rules

# %%
from sysdata.config.configdata import Config
from sysdata.sim.csv_futures_sim_data import csvFuturesSimData

# %%
profits=system.accounts.portfolio()
# Out:
# 2025-09-08 00:44:10 DEBUG base_system Following instruments are 'duplicate_markets' ['Another_thing', 'bad_thing']
# 2025-09-08 00:44:10 DEBUG base_system Following instruments are marked as 'ignore_instruments': not included: ['EXAMPLE']
# 2025-09-08 00:44:10 DEBUG base_system Following instruments removed entirely from sim: ['Another_thing', 'EXAMPLE', 'bad_thing']
# 2025-09-08 00:44:10 INFO base_system {'stage': 'accounts'} Calculating pandl for portfolio
# 2025-09-08 00:44:10 DEBUG base_system {'stage': 'positionSize'} Getting vol target
# 2025-09-08 00:44:10 DEBUG base_system {'stage': 'accounts', 'instrument_code': 'BITCOIN'} Calculating pandl for instrument for BITCOIN
# 2025-09-08 00:44:10 DEBUG base_system {'stage': 'portfolio', 'instrument_code': 'BITCOIN'} Calculating notional position for BITCOIN
# 2025-09-08 00:44:10 INFO base_system {'stage': 'portfolio', 'instrument_code': 'BITCOIN'} Calculating instrument weights
# ...

# %%
profits.percent.stats()
# Out:
# [[('min', '-15.01'),
#   ('max', '13.8'),
#   ('median', '0.02263'),
#   ('mean', '0.04749'),
#   ('std', '1.364'),
#   ('skew', '0.03123'),
#   ('ann_mean', '12.16'),
#   ('ann_std', '21.82'),
#   ('sharpe', '0.5571'),
#   ('sortino', '0.7295'),
#   ('avg_drawdown', '-26.62'),
#   ('time_in_drawdown', '0.9584'),
#   ('calmar', '0.09934'),
#   ('avg_return_to_drawdown', '0.4568'),
#   ('avg_loss', '-0.9091'),
#   ('avg_gain', '0.9155'),
#   ('gaintolossratio', '1.007'),
#   ('profitfactor', '1.113'),
#   ('hitrate', '0.525'),
#   ('t_stat', '4.034'),
#   ('p_value', '5.514e-05')],
#  ('You can also plot / print:',
#   ['rolling_ann_std', 'drawdown', 'curve', 'percent'])]

# %%
profits.percent.curve().plot()
# Out:
# <Axes: >
